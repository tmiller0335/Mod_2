# %%
import pandas as pd 
#This imports the Pandas library as we need it to show the data in a meaningful way.

import requests 
#This imports the Requests library, which is used for making HTTP requests (like getting data from websites or APIs). In this case, it will help us fetch data from a web API.

# %%
url = "https://meowfacts.herokuapp.com/?count=10"
#This line defines the URL from which we'll request data. The URL points to an API that provides random cat facts. 
#The query parameter ?count=10 specifies that we want 10 cat facts.

response = requests.get(url)
#This sends an HTTP GET request to the URL we defined earlier. 
#It fetches the data from the server and stores the response in the response variable.

# Check if the request was successful

if response.status_code == 200: #This checks the status of the response. HTTP status code 200 means "OK", indicating that the request was successful. If the request was successful, the program will continue to process the data.
    data = response.json() #If the request was successful, the response will contain data (usually in JSON format). This converts the JSON response into a Python dictionary (or list, depending on the structure).
    print('success!')
else:
    print(f"Error: {response.status_code}")
    # This prints the error message, displaying the actual HTTP status code (e.g., 404 for not found, 500 for server errors).


df = pd.DataFrame(data) #After successfully retrieving the data, we use Pandas to create a DataFrame.
print(df)
# Out:
# success!
#                                                 data
# 0  In ancient Egypt, when a family cat died, all ...
# 1  Today there are about 100 distinct breeds of t...
# 2  Many cats cannot properly digest cows milk. Mi...
# 3  In ancient Egypt, killing a cat was a crime pu...
# 4     Jaguars are the only big cats that don't roar.
# 5  The Maine Coone is the only native American lo...
# 6  Cats that live together sometimes rub each oth...
# 7  Julius Ceasar, Henri II, Charles XI, and Napol...
# 8  A cat can spend five or more hours a day groom...
# 9  There are cats who have survived falls from ov...
