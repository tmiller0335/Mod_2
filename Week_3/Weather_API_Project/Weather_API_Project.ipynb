# %%
baseurl = "https://api.weatherapi.com/v1"
key = "245921691a424ae4bc0192138251409"

# %%
import pandas as pd
import requests

# %%
city = "Louisville"
baseurl = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
response = requests.get(baseurl)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data
# Out:
# {'location': {'name': 'Louisville',
#   'region': 'Kentucky',
#   'country': 'United States of America',
#   'lat': 38.2542,
#   'lon': -85.7594,
#   'tz_id': 'America/Kentucky/Louisville',
#   'localtime_epoch': 1757880730,
#   'localtime': '2025-09-14 16:12'},
#  'current': {'last_updated_epoch': 1757880000,
#   'last_updated': '2025-09-14 16:00',
#   'temp_c': 30.6,
#   'temp_f': 87.1,
#   'is_day': 1,
#   'condition': {'text': 'Sunny',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#    'code': 1000},
#   'wind_mph': 2.2,
#   'wind_kph': 3.6,
#   'wind_degree': 16,
#   'wind_dir': 'NNE',
#   'pressure_mb': 1016.0,
#   'pressure_in': 29.99,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 48,
#   'cloud': 25,
#   'feelslike_c': 32.5,
#   'feelslike_f': 90.6,
#   'windchill_c': 32.9,
#   'windchill_f': 91.2,
#   'heatindex_c': 37.1,
#   'heatindex_f': 98.8,
#   'dewpoint_c': 22.0,
#   'dewpoint_f': 71.5,
#   'vis_km': 16.0,
#   'vis_miles': 9.0,
#   'uv': 4.2,
#   'gust_mph': 2.3,
#   'gust_kph': 3.7,
#   'short_rad': 739.52,
#   'diff_rad': 115.4,
#   'dni': 0.0,
#   'gti': 118.89}}

# %%
current = data['current']
location = data['location']
temp_f = current['temp_f']
temp_c = current['temp_c']
wind_mph = current['wind_mph']
humidity = current['humidity']

# %%
temp_f, humidity
# Out:
# (87.1, 48)

# %%
def get_weather(city):
    url = f"http://api.weatherapi.com/v1/current.json?key={key}&q={city}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        current = data['current'] 
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']  
        
        print(f"Weather for {location['name']}, {location['region']}")
        print(f"Tempature: {current['temp_f']}, °F / {current['temp_c']} °C")
        print(f"Condition: {current['condition']['text']}")
        print(f"Humidity: {current['humidity']}%")
        print(f"Wind Speed: {current['wind_mph']} mph")
    else:
        print(f"Error fetching data for {city}: {response.status_code}")

# %%
get_weather("Cleveland")
# Out:
# Weather for Cleveland, Ohio
# Tempature: 73.0, °F / 22.8 °C
# Condition: Sunny
# Humidity: 71%
# Wind Speed: 11.4 mph

# %%
get_weather("Elyria")
# Out:
# Weather for Elyria, Ohio
# Tempature: 79.0, °F / 26.1 °C
# Condition: Sunny
# Humidity: 45%
# Wind Speed: 12.1 mph

# %%
get_weather("Somerset")
# Out:
# Weather for Somerset West, Western Cape
# Tempature: 55.9, °F / 13.3 °C
# Condition: Partly Cloudy
# Humidity: 88%
# Wind Speed: 2.2 mph

# %%
get_weather("Basking Ridge")
# Out:
# Weather for Basking Ridge, New Jersey
# Tempature: 84.0, °F / 28.9 °C
# Condition: Cloudy
# Humidity: 45%
# Wind Speed: 3.1 mph
